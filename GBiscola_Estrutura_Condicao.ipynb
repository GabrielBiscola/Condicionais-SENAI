# %%
#O arquivo era pra estar em snake case?
#Leia dois números, faça a soma e apresente caso seja maior que 15.
n1=float(input("Entre com o primeiro número:"))
n2=float(input("Entre com o segundo número:"))
if (n1+n2) > 15:
  print(n1+n2)
# Out:
# Entre com o primeiro número:7.5
# Entre com o segundo número:7.6
# 15.1

# %%
#Faça um programa que recebendo um valor inteiro, informe se o número é positivo, negativo ou neutro.
n=int(input())
if n >= 0:
  if n > 0:
    print("Positivo")
  else:
    print("Neutro")
else:
  print("Negativo")
# Out:
# -9
# Negativo

# %%
#Leia a idade e informe se a pessoa é maior ou menor de idade
age=int(input("Digite a sua idade:"))
if age < 18:
  if age < 0:
    print("Pare de mentir a idade, fi.")
  else:
    print("Menor de idade.")
else:
  print("Maior de idade")
# Out:
# Digite a sua idade:-1
# Para de mentir a idade, fi.

# %%
#Faça um programa que pergunte a temperatura atual para o usuário e mostre uma mensagem na tela dizendo se está “quente”, “frio” ou “agradável”
temperatura=float(input("Qual é a temperatura atual? (em Celsius)"))
if temperatura <= 25 and temperatura >= 20:
  print("Ta tranquilo, ta favoravel.")
elif temperatura < 20:
  print("Friozin")
else:
  print("Calor")
# Out:
# Qual é a temperatura atual? (em Celsius)24
# Ta tranquilo, ta favoravel.

# %%
#Faça um programa em linguagem Python que leia dois números inteiros e informe
n1=int(input("Entre com o primeiro número:"))
n2=int(input("Entre com o segundo número:"))
if n1 == n2:
  #Testando as diferentes formas de formatacao
  print(f"{n1} e {n2} sao o mesmo numero.")
else:
  print("{} e {} sao numeros diferentes.".format(n1, n2))
# Out:
# Entre com o primeiro número:2
# Entre com o segundo número:2
# 2 e 2 sao o mesmo numero.

# %%
#Escreva um programa que verifique a validade de uma senha fornecida pelo
#usuário. A senha válida é o número 1234. Devem ser impressas as seguintes
#mensagens:
# ACESSO PERMITIDO caso a senha seja válida.
# ACESSO NEGADO caso a senha seja inválida.
senha = input("USUARIO:USER\nSENHA:")
if senha == "1234":
  print("ACESSO PERMITIDO")
else:
  print("ACESSO NEGADO")
# Out:
# USUARIO:USER
# SENHA:1234
# ACESSO PERMITIDO

# %%
#Ler duas notas de um aluno, efetuar a média aritmética e, se a média for maior ou
#igual a 7, informar que o aluno foi aprovado; se a média for maior ou igual a 5 mas
#menor do que 7, informar que o aluno está de exame; se a média for menor do que
#5 informar que o aluno foi reprovado.
nota1 = float(input("Digite a sua primeira nota:"))
nota2 = float(input("Digite a sua segunda nota:"))
media = (nota1+nota2)/2
if media >= 5:
  if media < 7:
    print("Voce esta de exame")
  else:
    print("Parabens, voce passou")
else:
  print("Faz o L (versao brasileira do 'take the L').\nEm outras palavras, voce foi de Santos.")
# Out:
# Digite a sua primeira nota:7
# Digite a sua segunda nota:6
# Voce esta de exame

# %%
#Desenvolva um programa que recebe do usuário o placar de um jogo de futebol (os
#gols de cada time) e informe se o resultado foi um empate, se a vitória foi do
#primeiro time ou do segundo time
time1 = input("Qual era o time da casa?").title()
gols1 = input("Quantos gols ele fez?")
time2 = input("Qual era o time visitante?").title()
gols2 = input("Quantos gols ele fez?")
if time1 != "Corinthians" and time2 != "Corinthians": #O corinthians perdeu 5 seguidas, como pode
  if gols1 > gols2:
    print(f"O {time1} venceu!")
  elif gols1 < gols2:
    print(f"O {time2} venceu!")
  else:
    print("Empate!")
else:
  #Delirios e entretenimento
  print("O Corinthians perdeu. Eu nao aguento mais ser corintiano, Deus me ajude.\n'Não há nada que deprima mais o ser humano (mais depressa)\ndo que a paixão pelo Corinthians'.\n\t\t\t- Friedrich Nietzsche")
print(f"\nPlacar:{gols1} X {gols2}")
# Out:
# Qual era o time da casa?Vaso
# Quantos gols ele fez?2
# Qual era o time visitante?Palmeras
# Quantos gols ele fez?4
# O Palmeras venceu!
#
# Placar:2 X 4

# %%
#Faça um Programa que pergunte em que turno você estuda. Peça para digitar Mmatutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa
#Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.
turnos = ["m","v","n"]
turno=input("Em qual turno voce estuda? (m / v / n)").lower()
if turno in turnos:
  if turno == "m":
    print("Bom Dia!")
  elif turno == "v":
    print("Boa Tarde!")
  else:
    print("Boa Noite!")
else:
  print("Valor Invalido! (Digite como indica o primeiro comando)")
# Out:
# Em qual turno voce estuda? (m / v / n)M
# Bom Dia!

# %%
# Faça um programa que solicite ao usuário sua idade, depois disso, exiba a
# classificação etária de acordo com as faixas de valores:
# Criança para 0 até 11 anos;
# Adolescente para 12 até 18 anos;
# Jovem para 19 até 24 anos;
# Adulto para 25 até 40 anos;
# Meia Idade para 41 até 60 anos;
# Idoso acima de 60 anos
idade = int(input("Qual e a sua idade?"))
#Jovem pra baixo
if idade < 25 and idade >= 0:
  if idade < 19:
    if idade < 12:
      print("Voce e uma crianca")
    else:
      print("Voce e um adolescente")
  else:
    print("Voce e um jovem")
#Adulto pra cima
elif idade > 24:
  if idade <= 60:
    if idade <= 40:
      print("Voce e um adulto")
    else:
      print("Voce tem meia idade")
  else:
    print("Voce e um idoso! (falando assim, soa pejorativo)")
else:
  print("Idade invalida!")
# Out:
# Qual e a sua idade?-1
# Idade invalida!

# %%
"""
As Organizações Tabajara resolveram dar um aumento de salário aos seus
colaboradores e lhe contrataram para desenvolver o programa que calculará os
reajustes. Faça um programa que recebe o salário de um colaborador e o reajuste
segundo o seguinte critério, baseado no salário atual:
 salários até R$ 280,00 (incluindo) : aumento de 20%
 salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
 salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
 salários de R$ 1500,00 em diante : aumento de 5%
Após o aumento ser realizado, informe na tela:
 o salário antes do reajuste;
 o percentual de aumento aplicado;
 o valor do aumento;
 o novo salário, após o aumento.
"""
#Muito texto, foi mal
salario = float(input("Qual e o seu salario?"))
#A cabeca ja ta cansando aqui
if salario < 1500:
  if salario < 700:
    if salario <= 280:
      porcento=20/100
    else:
      porcento=15/100
  else:
    porcento=10/100
else:
  porcento=5/100

aumento=porcento*salario
salarioFinal=salario+aumento
print("")
print(f"O seu salario era de R${salario}\nO Aumento em porcentagem foi de {porcento*100:.0f}%\nO Aumento em reais foi de R${aumento}\nO novo salario e de R${salarioFinal}")
# Out:
# Qual e o seu salario?1500
#
# O seu salario era de R$1500.0
# O Aumento em porcentagem foi de 5%
# O Aumento em reais foi de R$75.0
# O novo salario e de R$1575.0

# %%
#Faça um Programa que leia um número e exiba o dia correspondente da semana.
#(1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.
semana = [1, 2, 3, 4, 5 ,6 ,7]
n = int(input("Digite um numero respectivo a um dia da semana"))
if n in semana:
  if n == 1:
    print("Domingo")
  elif n == 2:
    print("Segunda")
  elif n == 3:
    print("Terca")
  elif n == 4:
    print("Quarta")
  elif n == 5:
    print("Quinta")
  elif n == 6:
    print("Sexta")
  else:
    print("Sabado")
else:
  print("Valor Invalido")
# Out:
# Digite um numero respectivo a um dia da semana9
# Valor Invalido

# %%
#Faça um programa que pergunte ao usuário se ele quer passar uma temperatura de
#Fahrenheit para Celsius ou de Celsius para Fahrenheit, e que, a partir da resposta
#do usuário, faça a devida conversão.
temperatura = float(input("Entre com a temperatura:"))
escala = input("A temperatura esta em celsius (c) ou fahrenheit (f)?").upper()
if escala == "C":
  conversao = (temperatura * 1.8) + 32
  escalaFinal = "°F"
elif escala == "F":
  conversao = (temperatura - 32)/1.8
  escalaFinal = "°C"
else:
  print("Escala nao reconhecida")
print(f"{temperatura}°{escala} é equivalente a {conversao:.2f}{escalaFinal}")
# Out:
# Entre com a temperatura:55
# A temperatura esta em celsius (c) ou fahrenheit (f)?F
# 55.0°f é equivalente a 12.78°C

# %%
# Faça um programa que receba a idade de uma pessoa e imprima sua condição
# (obrigatória, optativa ou proibida), em relação ao ato de votar, conforme
# apresentado abaixo:
#  Pessoas com idade menor que 16 anos são proibidas de votar (proibido);
#  Pessoas com idade igual a 16 e menor que 18 anos não são obrigadas a votar
# (optativo);
#  Pessoas com idade igual a 18 e menor que 65 anos são obrigadas a votar
# (obrigatório);
#  Pessoas com idade igual ou maior a 65 anos não são obrigadas a votar (optativo).
idade = int(input("Qual é a sua idade?"))
if idade < 65 and idade > 17:
  print("O voto é obrigatório para você.")
elif idade < 16:
  print("O voto é proibido para você.")
else:
  print("O voto é facultativo para você.")
# Out:
# Qual é a sua idade?18
# O voto é facultativo para você.

# %%
# Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As
# perguntas são:
#  “Telefonou para a vítima? “
#  “Esteve no local do crime?”
#  “Mora perto da vítima? “
#  “Devia para a vítima? “
#  “Já trabalhou com a vítima? “
# O programa deve no final emitir uma classificação sobre a participação da pessoa
# no crime. Se a pessoa responder positivamente a 2 questões ela deve ser
# classificada como “Suspeita”, entre 3 e 4 como “Cúmplice” e 5 como “Assassino“.
# Caso contrário, ele será classificado como “Inocente“.
pontos = 0
print("Utilize 0 para nao e 1 para sim. Qualquer coisa que fuja disso, nao resultara em um resultado fidedigno.")
tel = int(input("Telefonou para a vítima?"))
local = int(input("Esteve no local do crime?"))
casa = int(input("Mora perto da vítima"))
devia = int(input("Devia para a vítima?"))
trabalho = int(input("Já trabalhou com a vítima?"))
pontos = tel+local+casa+devia+trabalho
if pontos >= 2:
  if pontos > 2:
    if pontos < 5:
      tag = "cumplice"
    else:
      tag = "assassino"
else:
  tag = "inocente"
print(f"Voce foi classificado como {tag}")
#Dava pra fazer de outra forma, mas agora ja foi
# Out:
# Utilize 0 para nao e 1 para sim. Qualquer coisa que fuja disso, nao resultara em um resultado fidedigno.
# Telefonou para a vítima?1
# Esteve no local do crime?0
# Mora perto da vítima0
# Devia para a vítima?0
# Já trabalhou com a vítima?0
# Voce foi classificado como inocente

# %%
# Faça um programa que pergunte o preço de três produtos e informe qual produto
# você deve comprar, sabendo que a decisão é sempre pelo mais barato.
print("Bem vindo ao mao de vaca simulator, aqui te ajudaremos a sempre optar pelo mais barato!\nCadastre tres produtos:")
p1Nome = str(input("Nome do produto 1:"))
p1Preco = float(input("Preco do produto 1:"))
p2Nome = str(input("Nome do produto 2:"))
p2Preco = float(input("Preco do produto 2:"))
p3Nome = str(input("Nome do produto 3:"))
p3Preco = float(input("Preco do produto 3:"))
if p1Preco < p2Preco and p1Preco < p3Preco:
  barato = p1Nome
  baratoPreco = p1Preco
elif p2Preco < p1Preco and p2Preco < p3Preco:
  barato = p2Nome
  baratoPreco = p2Preco
elif p3Preco < p1Preco and p3Preco < p2Preco:
  barato = p3Nome
  baratoPreco = p3Preco
print(f"O produto mais em conta é o/a {barato}. É o produto mais barato e custa {baratoPreco}.")
# Out:
# Bem vindo ao mao de vaca simulator, aqui te ajudaremos a sempre optar pelo mais barato!
# Cadastre tres produtos:
# Nome do produto 1:Pao
# Preco do produto 1:20
# Nome do produto 2:pao frances
# Preco do produto 2:.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-aa1260804662> in <cell line: 7>()
#       5 p1Preco = float(input("Preco do produto 1:"))
#       6 p2Nome = str(input("Nome do produto 2:"))
# ----> 7 p2Preco = float(input("Preco do produto 2:"))
#       8 p3Nome = str(input("Nome do produto 3:"))
#       9 p3Preco = float(input("Preco do produto 3:"))
#
# ValueError: could not convert string to float: '.'
